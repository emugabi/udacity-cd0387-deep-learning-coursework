# %%
from sagemaker.pytorch import PyTorch
from sagemaker import get_execution_role

hyperparameters = {"epochs" : "2", "batch-size": "32", "test-batch-size": "100",
                  "lr": "0.004"}# TODO: Include the hyperparameters your script will need over here.

estimator = PyTorch(
    entry_point="pytorch_cifar.py",
    base_job_name="sagemaker-script-mode",
    role=get_execution_role(),
    instance_count=1,
    instance_type="ml.m5.large",
    hyperparameters=hyperparameters,
    framework_version="1.8",
    py_version="py36",
)

estimator.fit(wait=True)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: sagemaker-script-mode-2024-03-24-12-25-07-571
# 2024-03-24 12:25:08 Starting - Starting the training job...
# 2024-03-24 12:25:23 Starting - Preparing the instances for training...
# 2024-03-24 12:25:54 Downloading - Downloading input data...
# 2024-03-24 12:26:29 Downloading - Downloading the training image......
# 2024-03-24 12:27:35 Training - Training image download completed. Training in progress.
# 2024-03-24 12:27:35 Uploading - Uploading generated training modelbash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2024-03-24 12:27:23,129 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2024-03-24 12:27:23,132 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-03-24 12:27:23,140 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2024-03-24 12:27:23,143 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2024-03-24 12:27:23,322 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-03-24 12:27:23,335 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-03-24 12:27:23,345 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-03-24 12:27:23,354 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch-size": "32",
#         "epochs": "2",
#         "lr": "0.004",
#         "test-batch-size": "100"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-script-mode-2024-03-24-12-25-07-571",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-433073421675/sagemaker-script-mode-2024-03-24-12-25-07-571/source/sourcedir.tar.gz",
#     "module_name": "pytorch_cifar",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.large",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.large",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "pytorch_cifar.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":"32","epochs":"2","lr":"0.004","test-batch-size":"100"}
# SM_USER_ENTRY_POINT=pytorch_cifar.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=pytorch_cifar
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-433073421675/sagemaker-script-mode-2024-03-24-12-25-07-571/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch-size":"32","epochs":"2","lr":"0.004","test-batch-size":"100"},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-script-mode-2024-03-24-12-25-07-571","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-433073421675/sagemaker-script-mode-2024-03-24-12-25-07-571/source/sourcedir.tar.gz","module_name":"pytorch_cifar","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0"},"user_entry_point":"pytorch_cifar.py"}
# SM_USER_ARGS=["--batch-size","32","--epochs","2","--lr","0.004","--test-batch-size","100"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_BATCH-SIZE=32
# SM_HP_EPOCHS=2
# SM_HP_LR=0.004
# SM_HP_TEST-BATCH-SIZE=100
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 pytorch_cifar.py --batch-size 32 --epochs 2 --lr 0.004 --test-batch-size 100
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ../data/cifar-10-python.tar.gz
# Extracting ../data/cifar-10-python.tar.gz to ../data
# [2024-03-24 12:27:29.152 algo-1:27 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-03-24 12:27:29.324 algo-1:27 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2024-03-24 12:27:29.325 algo-1:27 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2024-03-24 12:27:29.325 algo-1:27 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2024-03-24 12:27:29.326 algo-1:27 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [2024-03-24 12:27:29.326 algo-1:27 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2024-03-24 12:27:29.331 algo-1:27 INFO hook.py:591] name:conv1.weight count_params:288
# [2024-03-24 12:27:29.331 algo-1:27 INFO hook.py:591] name:conv1.bias count_params:32
# [2024-03-24 12:27:29.331 algo-1:27 INFO hook.py:591] name:conv2.weight count_params:18432
# [2024-03-24 12:27:29.332 algo-1:27 INFO hook.py:591] name:conv2.bias count_params:64
# [2024-03-24 12:27:29.332 algo-1:27 INFO hook.py:591] name:fc1.weight count_params:1179648
# [2024-03-24 12:27:29.332 algo-1:27 INFO hook.py:591] name:fc1.bias count_params:128
# [2024-03-24 12:27:29.332 algo-1:27 INFO hook.py:591] name:fc2.weight count_params:1280
# [2024-03-24 12:27:29.332 algo-1:27 INFO hook.py:591] name:fc2.bias count_params:10
# [2024-03-24 12:27:29.332 algo-1:27 INFO hook.py:593] Total Trainable Params: 1199882
# [2024-03-24 12:27:29.332 algo-1:27 INFO hook.py:425] Monitoring the collections: losses
# [2024-03-24 12:27:29.335 algo-1:27 INFO hook.py:488] Hook is writing from the hook with pid: 27
# #015  0%|          | 0/170498071 [00:00<?, ?it/s]#015  0%|          | 657408/170498071 [00:00<00:25, 6573866.84it/s]#015  4%|▍         | 7223296/170498071 [00:00<00:03, 41328562.59it/s]#015  9%|▉         | 15848448/170498071 [00:00<00:02, 61815370.14it/s]#015 14%|█▍        | 24536064/170498071 [00:00<00:02, 71676520.37it/s]#015 20%|█▉        | 33840128/170498071 [00:00<00:01, 79229371.17it/s]#015 25%|██▌       | 43152384/170498071 [00:00<00:01, 83939202.59it/s]#015 31%|███       | 52408320/170498071 [00:00<00:01, 86741703.02it/s]#015 36%|███▌      | 61639680/170498071 [00:00<00:01, 88513879.29it/s]#015 41%|████▏     | 70491136/170498071 [00:00<00:01, 87905470.02it/s]#015 47%|████▋     | 79283200/170498071 [00:01<00:01, 87487787.76it/s]#015 52%|█████▏    | 88033280/170498071 [00:01<00:00, 87273584.39it/s]#015 57%|█████▋    | 96761856/170498071 [00:01<00:00, 86733706.24it/s]#015 62%|██████▏   | 105564160/170498071 [00:01<00:00, 87120770.67it/s]#015 67%|██████▋   | 114352128/170498071 [00:01<00:00, 87288935.76it/s]#015 73%|███████▎  | 124032000/170498071 [00:01<00:00, 90117324.35it/s]#015 78%|███████▊  | 133096448/170498071 [00:01<00:00, 90270486.05it/s]#015 83%|████████▎ | 142336000/170498071 [00:01<00:00, 90885526.27it/s]#015 89%|████████▉ | 151520256/170498071 [00:01<00:00, 91090112.76it/s]#015 94%|█████████▍| 160630784/170498071 [00:01<00:00, 90336898.08it/s]#015100%|█████████▉| 169666560/170498071 [00:02<00:00, 89277704.59it/s]#015170499072it [00:02, 84271165.24it/s]
# Traceback (most recent call last):
#   File "pytorch_cifar.py", line 124, in <module>
#     main()
#   File "pytorch_cifar.py", line 119, in main
#     train(model, train_loader, optimizer, epoch)
#   File "pytorch_cifar.py", line 38, in train
#     output = model(data)
#   File "/opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py", line 918, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "pytorch_cifar.py", line 20, in forward
#     x = self.conv1(x)
#   File "/opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py", line 918, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/opt/conda/lib/python3.6/site-packages/torch/nn/modules/conv.py", line 399, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#   File "/opt/conda/lib/python3.6/site-packages/torch/nn/modules/conv.py", line 396, in _conv_forward
#     self.padding, self.dilation, self.groups)
# RuntimeError: Given groups=1, weight of size [32, 1, 3, 3], expected input[32, 3, 32, 32] to have 1 channels, but got 3 channels instead
# 2024-03-24 12:27:29,483 sagemaker-training-toolkit ERROR    ExecuteUserScriptError:
# Command "/opt/conda/bin/python3.6 pytorch_cifar.py --batch-size 32 --epochs 2 --lr 0.004 --test-batch-size 100"
# #015  0%|          | 0/170498071 [00:00<?, ?it/s]#015  0%|          | 657408/170498071 [00:00<00:25, 6573866.84it/s]#015  4%|â         | 7223296/170498071 [00:00<00:03, 41328562.59it/s]#015  9%|â         | 15848448/170498071 [00:00<00:02, 61815370.14it/s]#015 14%|ââ        | 24536064/170498071 [00:00<00:02, 71676520.37it/s]#015 20%|ââ        | 33840128/170498071 [00:00<00:01, 79229371.17it/s]#015 25%|âââ       | 43152384/170498071 [00:00<00:01, 83939202.59it/s]#015 31%|âââ       | 52408320/170498071 [00:00<00:01, 86741703.02it/s]#015 36%|ââââ      | 61639680/170498071 [00:00<00:01, 88513879.29it/s]#015 41%|âââââ     | 70491136/170498071 [00:00<00:01, 87905470.02it/s]#015 47%|âââââ     | 79283200/170498071 [00:01<00:01, 87487787.76it/s]#015 52%|ââââââ    | 88033280/170498071 [00:01<00:00, 87273584.39it/s]#015 57%|ââââââ    | 96761856/170498071 [00:01<00:00, 86733706.24it/s]#015 62%|âââââââ   | 105564160/170498071 [00:01<00:00, 87120770.67it/s]#015 67%|âââââââ   | 114352128/170498071 [00:01<00:00, 87288935.76it/s]#015 73%|ââââââââ  | 124032000/170498071 [00:01<00:00, 90117324.35it/s]#015 78%|ââââââââ  | 133096448/170498071 [00:01<00:00, 90270486.05it/s]#015 83%|âââââââââ | 142336000/170498071 [00:01<00:00, 90885526.27it/s]#015 89%|âââââââââ | 151520256/170498071 [00:01<00:00, 91090112.76it/s]#015 94%|ââââââââââ| 160630784/170498071 [00:01<00:00, 90336898.08it/s]#015100%|ââââââââââ| 169666560/170498071 [00:02<00:00, 89277704.59it/s]#015170499072it [00:02, 84271165.24it/s]
# Traceback (most recent call last):
#   File "pytorch_cifar.py", line 124, in <module>
#     main()
#   File "pytorch_cifar.py", line 119, in main
#     train(model, train_loader, optimizer, epoch)
#   File "pytorch_cifar.py", line 38, in train
#     output = model(data)
#   File "/opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py", line 918, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "pytorch_cifar.py", line 20, in forward
#     x = self.conv1(x)
#   File "/opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py", line 918, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/opt/conda/lib/python3.6/site-packages/torch/nn/modules/conv.py", line 399, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#   File "/opt/conda/lib/python3.6/site-packages/torch/nn/modules/conv.py", line 396, in _conv_forward
#     self.padding, self.dilation, self.groups)
# RuntimeError: Given groups=1, weight of size [32, 1, 3, 3], expected input[32, 3, 32, 32] to have 1 channels, but got 3 channels instead
#
# 2024-03-24 12:27:48 Failed - Training job failed
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# Cell In[1], line 18
#       4 hyperparameters = {"epochs" : "2", "batch-size": "32", "test-batch-size": "100",
#       5                   "lr": "0.004"}# TODO: Include the hyperparameters your script will need over here.
#       7 estimator = PyTorch(
#       8     entry_point="pytorch_cifar.py",
#       9     base_job_name="sagemaker-script-mode",
#    (...)
#      15     py_version="py36",
#      16 )
# ---> 18 estimator.fit(wait=True)
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/workflow/pipeline_context.py:346, in runnable_by_pipeline.<locals>.wrapper(*args, **kwargs)
#     342         return context
#     344     return _StepArguments(retrieve_caller_name(self_instance), run_func, *args, **kwargs)
# --> 346 return run_func(*args, **kwargs)
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/estimator.py:1341, in EstimatorBase.fit(self, inputs, wait, logs, job_name, experiment_config)
#    1339 self.jobs.append(self.latest_training_job)
#    1340 if wait:
# -> 1341     self.latest_training_job.wait(logs=logs)
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/estimator.py:2677, in _TrainingJob.wait(self, logs)
#    2675 # If logs are requested, call logs_for_jobs.
#    2676 if logs != "None":
# -> 2677     self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    2678 else:
#    2679     self.sagemaker_session.wait_for_job(self.job_name)
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/session.py:5568, in Session.logs_for_job(self, job_name, wait, poll, log_type, timeout)
#    5547 def logs_for_job(self, job_name, wait=False, poll=10, log_type="All", timeout=None):
#    5548     """Display logs for a given training job, optionally tailing them until job is complete.
#    5549
#    5550     If the output is a tty or a Jupyter cell, it will be color-coded
#    (...)
#    5566         exceptions.UnexpectedStatusException: If waiting and the training job fails.
#    5567     """
# -> 5568     _logs_for_job(self, job_name, wait, poll, log_type, timeout)
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/session.py:7711, in _logs_for_job(sagemaker_session, job_name, wait, poll, log_type, timeout)
#    7708             last_profiler_rule_statuses = profiler_rule_statuses
#    7710 if wait:
# -> 7711     _check_job_status(job_name, description, "TrainingJobStatus")
#    7712     if dot:
#    7713         print()
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/session.py:7764, in _check_job_status(job, desc, status_key_name)
#    7758 if "CapacityError" in str(reason):
#    7759     raise exceptions.CapacityError(
#    7760         message=message,
#    7761         allowed_statuses=["Completed", "Stopped"],
#    7762         actual_status=status,
#    7763     )
# -> 7764 raise exceptions.UnexpectedStatusException(
#    7765     message=message,
#    7766     allowed_statuses=["Completed", "Stopped"],
#    7767     actual_status=status,
#    7768 )
#
# UnexpectedStatusException: Error for Training job sagemaker-script-mode-2024-03-24-12-25-07-571: Failed. Reason: AlgorithmError: ExecuteUserScriptError:
# Command "/opt/conda/bin/python3.6 pytorch_cifar.py --batch-size 32 --epochs 2 --lr 0.004 --test-batch-size 100"
#  52%|ââââââ    , exit code: 1
